# %% [markdown]
# ## Iteration per countries - return pandas - annual values

# %%
import pandas as pd
from bentso import CachingDataClient
c = CachingDataClient()

# %%
## Get list of countries
## ISO list of countries
countries = ['AT','BE','BA','BG','HR','CY','CZ','DK','EE','FI','FR','DE','GR','HU','IE','IS','IT','LV','LU','MK','ME','NL','NI','NO','PL','PT','RO','RS','SK','SI','SE','CH'];
countries
# Out:
# ['AT',
#  'BE',
#  'BA',
#  'BG',
#  'HR',
#  'CY',
#  'CZ',
#  'DK',
#  'EE',
#  'FI',
#  'FR',
#  'DE',
#  'GR',
#  'HU',
#  'IE',
#  'IS',
#  'IT',
#  'LV',
#  'LU',
#  'MK',
#  'ME',
#  'NL',
#  'NI',
#  'NO',
#  'PL',
#  'PT',
#  'RO',
#  'RS',
#  'SK',
#  'SI',
#  'SE',
#  'CH']

# %%
def InterateCountriesProduction(year):
    # countries = ['AT','BE','BA','BG','HR','CY','CZ','DK','EE','FI','FR','DE','GR','HU','IE','IS','IT','LV','LU','MK','ME','NL','NI','NO','PL','PT','RO','RS','SK','SI','SE','CH'];
    countries = ['ES','FR'];
    mom = list()
    for ctr in countries:
        ctr_year = c.get_generation(ctr, year)
        x = ctr_year.sum()
        a = list(x.index)
        s = pd.Series(ctr)
        pap =  pd.DataFrame(data={'technology': list(x.index), 'country': list(s.repeat(len(x.index))), 'energy_MJ': list(x)})
        mom.append(pap)
    
    df = pd.concat(mom, ignore_index=True)
    return(df)

# %%
def InterateCountriesTrade(year):
    # countries = ['AT','BE','BA','BG','HR','CY','CZ','DK','EE','FI','FR','DE','GR','HU','IE','IS','IT','LV','LU','MK','ME','NL','NI','NO','PL','PT','RO','RS','SK','SI','SE','CH'];
    countries = ['ES','FR'];
    mom = list()
    for fromCtr in countries:
        for toCtr in countries:
            if(fromCtr != toCtr):
                trd_year = c.get_trade(fromCtr, toCtr, year)
                x = trd_year.sum()
                pap =  pd.DataFrame(data={'fromCountry': fromCtr, 'toCountry': toCtr, 'energy_MJ':x}, index=[0])
                mom.append(pap)
    
    df = pd.concat(mom, ignore_index=True)
    return(df)

# %%
InterateCountriesProduction(2017)
# Out:
#                          technology country    energy_MJ
# 0                           Biomass      ES    2982558.0
# 1         Fossil Brown coal/Lignite      ES    4768099.0
# 2           Fossil Coal-derived gas      ES          0.0
# 3                        Fossil Gas      ES   56709615.0
# 4                  Fossil Hard coal      ES   37966977.0
# 5                        Fossil Oil      ES    2581851.0
# 6                  Fossil Oil shale      ES          0.0
# 7                       Fossil Peat      ES          0.0
# 8                        Geothermal      ES          0.0
# 9              Hydro Pumped Storage      ES    3664273.0
# 10  Hydro Run-of-river and poundage      ES    6731314.0
# 11            Hydro Water Reservoir      ES   14046088.0
# 12                           Marine      ES          0.0
# 13                          Nuclear      ES   55592146.0
# 14                            Other      ES     431583.0
# 15                  Other renewable      ES     830384.0
# 16                            Solar      ES   13097815.0
# 17                            Waste      ES    2607498.0
# 18                    Wind Offshore      ES          0.0
# 19                     Wind Onshore      ES   47129965.0
# 20                          Biomass      FR    3049829.0
# 21                       Fossil Gas      FR   40944099.0
# 22                 Fossil Hard coal      FR    9690830.0
# 23                       Fossil Oil      FR    2429735.0
# 24             Hydro Pumped Storage      FR   11409452.0
# 25  Hydro Run-of-river and poundage      FR   35113619.0
# 26            Hydro Water Reservoir      FR   12496661.0
# 27                          Nuclear      FR  377999908.0
# 28                            Solar      FR    8904730.0
# 29                            Waste      FR    2108578.0
# 30                     Wind Onshore      FR   22833899.0

# %%
InterateCountriesTrade(2017)
# Out:
#   fromCountry toCountry   energy_MJ
# 0          ES        FR   2850276.0
# 1          FR        ES  15157686.0
