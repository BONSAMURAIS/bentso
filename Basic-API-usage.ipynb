# %%
# %matplotlib inline

# %%
from bentso.client import pd_client, pd

# %%
start = pd.Timestamp('20171201', tz='Europe/Brussels')
end = pd.Timestamp('20180101', tz='Europe/Brussels')

# %%
pt_es = pd_client.query_crossborder_flows("PT", "ES", start=start, end=end)
es_pt = pd_client.query_crossborder_flows("ES", "PT", start=start, end=end)

# %%
es_fr = pd_client.query_crossborder_flows("ES", "FR", start=start, end=end)
fr_es = pd_client.query_crossborder_flows("FR", "ES", start=start, end=end)

# %%
pt_es.plot()
# Out:
# /Users/cmutel/miniconda3/envs/bentso/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
es_pt.plot()

# %%
es_fr.plot()

# %%
fr_es.plot()
