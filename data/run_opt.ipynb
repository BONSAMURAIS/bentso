# %%
from bentso.iterations_with_opt import InterateCountriesProduction_with_phs_consumption_subtract
from bentso import CachingDataClient
# from bentso.storage_abstract_model import PHS_consumption_subtraction

# %%
c = CachingDataClient()
# Out:
# Using data directory /home/pangui/.local/share/bentso

# %%
InterateCountriesProduction_with_phs_consumption_subtract(c,2016)
# Out:
# Starting with AT  2016
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(AT,2016)
# Starting with BA  2016
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_generation(BA,2016)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(BA,2016)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_capacity(BA,2016)
# Starting with BE  2016
# Starting with BG  2016
# Row length of electricity price and generation do not match...
# Starting with BY  2016
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_generation(BY,2016)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(BY,2016)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_capacity(BY,2016)
# Starting with CH  2016
# ...

# %%
InterateCountriesProduction_with_phs_consumption_subtract(c,2017)
# Out:
# Starting with AT  2017
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(AT,2017)
# Starting with BA  2017
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(BA,2017)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_capacity(BA,2017)
# Starting with BE  2017
# Starting with BG  2017
# Row length of electricity price and generation do not match...
# Starting with BY  2017
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_generation(BY,2017)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(BY,2017)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_capacity(BY,2017)
# Starting with CH  2017
# Row length of electricity price and generation do not match...
# Starting with CZ  2017
# ...

# %%
InterateCountriesProduction_with_phs_consumption_subtract(c,2018)
# Out:
# Starting with AT  2018
# Row length of electricity price and generation do not match...
# Starting with BA  2018
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(BA,2018)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_capacity(BA,2018)
# Starting with BE  2018
# Starting with BG  2018
# Row length of electricity price and generation do not match...
# Starting with BY  2018
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_generation(BY,2018)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_day_ahead_prices(BY,2018)
# Querying ENTSO-E API. Please be patient...
# Not available data in ENTSO-e for c.get_capacity(BY,2018)
# Starting with CH  2018
# Starting with CZ  2018
# Row length of electricity price and generation do not match...
# Starting with DE  2018
# ...
